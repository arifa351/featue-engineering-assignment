# %% [markdown]
# # **Assignment Questions**

# %% [markdown]
# ### 1. What is a parameter?
#
# - In Machine Learning, a parameter is an internal variable of a model that is learned from training data. For example, in linear regression, the slope and intercept are parameters.
#
# ### 2. What is correlation? What does negative correlation mean?
#
# - Correlation measures the strength and direction of a linear relationship between two variables. It ranges from -1 to 1.
#
# - A negative correlation means that as one variable increases, the other decreases. For example, more study time might correlate negatively with the number of errors in a test.
#
# ### 3. Define Machine Learning. What are the main components in Machine Learning?
#
# - Machine Learning (ML) is a branch of AI that allows systems to learn and improve from experience without being explicitly programmed.
#
# - Main components:
#
#  - Data
#
#  - Model
#
#  - Loss Function
#
#  - Optimizer
#
#  - Evaluation Metrics
#
# ### 4. How does loss value help in determining whether the model is good or not?
#
# - Loss value measures the error between the predicted and actual outputs. A lower loss indicates a better-performing model.
#
# ### 5. What are continuous and categorical variables?
#
# - Continuous variables: Numerical values that can take any number (e.g., weight, age).
#
# - Categorical variables: Represent categories (e.g., gender, city).
#
# ### 6. How do we handle categorical variables in Machine Learning? What are the common techniques?
#
# - Techniques include:
#
#  - Label Encoding
#
#  - One-Hot Encoding
#
#  - Ordinal Encoding
#
# - These convert categories into numbers so models can use them.
#
# ### 7. What do you mean by training and testing a dataset?
#
# - Training data is used to train the model.
#
# - Testing data is used to evaluate how well the model generalizes to unseen data.
#
# ### 8. What is sklearn.preprocessing?
#
# - It's a module in scikit-learn that provides utilities for:
#
#  - Scaling
#
#  - Encoding
#
#  - Transforming data
#
# ### 9. What is a Test set?
#
# - The Test set is a portion of the data that is not seen by the model during training. It is used to evaluate the model's performance.
#
# ### 10. How do we split data for model fitting (training and testing) in Python?How do you approach a Machine Learning problem?
#
# - Using train_test_split() from sklearn.model_selection:
#
#  - from sklearn.model_selection import train_test_split
#
#  - X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
# - Steps:
#
#  - Understand the problem
#
#  - Collect and preprocess data
#
#  - Perform EDA (Exploratory Data Analysis)
#
#  - Select features
#
#  - Choose a model
#
#  - Train and evaluate
#
#  - Tune hyperparameters
#
#  - Deploy the model
#
# ### 11. Why do we have to perform EDA before fitting a model to the data?
#
# - EDA helps:
#
#  - Understand data distribution
#
#  - Detect missing/outlier values
#
#  - Discover relationships and patterns
#
#  - Decide which features to use or transform
#
# ### 12. What is correlation?
#
# - Correlation measures the strength and direction of a linear relationship between two variables. It ranges from -1 to 1.
#
# ### 13. What does negative correlation mean?
#
# - A negative correlation means that as one variable increases, the other decreases. For example, more study time might correlate negatively with the number of errors in a test.
#
# ### 14. How can you find correlation between variables in Python?
#
# - Using pandas:
#
#  - df.corr()
#
#  - import seaborn as sns
#  - sns.heatmap(df.corr(), annot=True)
#
# ### 15. What is causation? Explain the difference between correlation and causation with an example.
#
# - Causation means one variable directly affects another.
#
# - Correlation means two variables move together but not necessarily due to cause-effect.
#
# - Example:
#  - Ice cream sales and drowning rates correlate (both increase in summer), but one doesn't cause the other.
#
# ### 16. What is an Optimizer? What are different types of optimizers? Explain each with an example.
#
# - An optimizer updates model parameters to minimize the loss.
#
# - Common types:
#
#  - SGD: Basic optimizer using gradient descent.
#
#  - Adam: Combines momentum and RMSprop.
#
#  - RMSprop: Maintains learning rates using a moving average of gradients.
#
#  - optimizer = tf.keras.optimizers.Adam()
#
# ### 17. What is sklearn.linear_model?
#
# - sklearn.linear_model is a module in Scikit-learn that provides linear models for both regression and classification.
#
# - Common models include:
#
#  - LinearRegression - for predicting continuous values.
#
#  - LogisticRegression - for binary/multi-class classification.
#
#  - Ridge, Lasso, ElasticNet - for regularized regression.
#
# ### 18. What does model.fit() do? What arguments must be given?
#
# - model.fit(X, y) trains the model by learning from:
#
#  - X: input features (independent variables)
#
#  - y: target values (dependent variable)
#
# ### 19. What does model.predict() do? What arguments must be given?
#
# - model.predict(X) uses the trained model to make predictions for new/unseen data X.
#
# ### 20. What are continuous and categorical variables?
#
# - Continuous variables: Numerical values that can take any number (e.g., weight, age).
#
# - Categorical variables: Represent categories (e.g., gender, city).
#
#
# ### 21. What is feature scaling? How does it help in Machine Learning?
#
# - Feature scaling is the process of normalizing or standardizing feature values so that they lie within the same range.
#
# - Why it helps:
#
#  - Ensures fair comparison between features.
#
#  - Improves convergence speed in optimization.
#
#  - Essential for distance-based models (like KNN, SVM).
#
# ### 22. How do we perform scaling in Python?
#
# - Using scikit-learn's preprocessing module:
#
#  - Standard Scaling (mean = 0, std = 1):
#    - from sklearn.preprocessing import StandardScaler
#    - scaler = StandardScaler()
#    - X_scaled = scaler.fit_transform(X)
#
#  -  Min-Max Scaling (range 0 to 1):
#    - from sklearn.preprocessing import MinMaxScaler
#    - scaler = MinMaxScaler()
#    - X_scaled = scaler.fit_transform(X)
#
# ### 23. What is sklearn.preprocessing?
#
# - sklearn.preprocessing is a module that includes tools for data transformation and preparation, such as:
#
#  - Encoding: LabelEncoder, OneHotEncoder
#
#  - Scaling: StandardScaler, MinMaxScaler
#
#  - Imputation: SimpleImputer for missing values
#
#  - Example:
#    - from sklearn.preprocessing import StandardScaler, OneHotEncoder
#
#
# ### 24. How do we split data for model fitting (training and testing) in Python?
#
# - Using train_test_split() from sklearn.model_selection:
#
#  - from sklearn.model_selection import train_test_split
#
#  - X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
# ### 25. Explain data encoding?
#
# - Data encoding converts categorical variables into numerical values so that machine learning models can process them.
#
# - Types:
#
#  - Label Encoding: Converts categories into integers.
#
#  - One-Hot Encoding: Creates binary columns for each category.
